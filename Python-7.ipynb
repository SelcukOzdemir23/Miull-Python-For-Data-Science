# %% [markdown]
# # Veri-i Görselleştir

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### Kategorik değişkenler sutün grafik ile göster
#
# * count plot
#
# ### Sayısal Değişken :histogram box plot
#
# *

# %%
import seaborn as sns
import pandas as pd
df = sns.load_dataset("titanic")
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
df["sex"].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot: >

# %% [markdown]
# # Sayısal Değişken Görselleştir

# %%
plt.hist(df["age"])
# Out:
# (array([ 54.,  46., 177., 169., 118.,  70.,  45.,  24.,   9.,   2.]),
#  array([ 0.42 ,  8.378, 16.336, 24.294, 32.252, 40.21 , 48.168, 56.126,
#         64.084, 72.042, 80.   ]),
#  <BarContainer object of 10 artists>)

# %%
sns.histplot(df["age"])
# Out:
# <AxesSubplot: xlabel='age', ylabel='Count'>

# %%
plt.boxplot(df["fare"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x28c4d695960>,
#   <matplotlib.lines.Line2D at 0x28c4d695c00>],
#  'caps': [<matplotlib.lines.Line2D at 0x28c4d695ea0>,
#   <matplotlib.lines.Line2D at 0x28c4d696140>],
#  'boxes': [<matplotlib.lines.Line2D at 0x28c4d695690>],
#  'medians': [<matplotlib.lines.Line2D at 0x28c4d6963e0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x28c4d696680>],
#  'means': []}

# %%
sns.boxplot(df["fare"])
# Out:
# <AxesSubplot: >

# %% [markdown]
# # Description Of Matplotlib

# %%
import numpy as np
x = np.array((1,8))
y = np.array((0,150))

# %%
plt.plot(x,y,'o')

# %%
# marker
y = np.array([13,28,11,100])
plt.plot(y,marker="*")

# %%
# line

# %% [markdown]
# # SEABORN

# %%
df = sns.load_dataset("tips")
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.histplot(df["sex"])
# Out:
# <AxesSubplot: xlabel='sex', ylabel='Count'>

# %%
sns.countplot(x = "sex",data = df)
# Out:
# <AxesSubplot: xlabel='sex', ylabel='count'>

# %%
###Sayısal Değişkenler

# %%
sns.boxplot(x = "total_bill",data=df)
# Out:
# <AxesSubplot: xlabel='total_bill'>

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [25], line 3
#       1 import seaborn as sns
# ----> 3 tips = sns.DataFrame("tips")
#
# AttributeError: module 'seaborn' has no attribute 'DataFrame'
